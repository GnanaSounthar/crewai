# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1
)

# %%
from crewai import Agent,Task,Crew


research_agent=Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic:{topic}",
    backstory="you are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm,
)

writer_agent=Agent(
    role="Creative Writer",
    goal="write a short blog summary using the reasearch",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    verbose=True,
    llm=llm,
)

# %%
from crewai import Crew, Task

# Define the tasks
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic} as of the year 2025.",
    expected_output="A bullet list of 3-5 facts.",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary.",
    agent=writer_agent,
    context=[task1],
)

# Create the crew
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

# Run the crew
result = crew.kickoff(inputs={"topic": "The future of electric vehicles"})

print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: cb069003-80a5-472e-bf81-ac3d0ed9c432                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electric vehicles as of the year 2025.         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# Trace batch initialization returned status 401. Continuing without tracing.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 3 interesting facts about the future of electric vehicles as of 2025:                                 │
# │                                                                                                                 │
# │  *   **Global EV Sales Projected to Surge:** By 2025, global electric vehicle sales are projected to reach      │
# │  over 20 million units, representing a significant increase from current levels. This growth is driven by       │
# │  factors such as decreasing battery costs, increasing availability of charging infrastructure, and growing      │
# │  consumer demand.                                                                                               │
# │                                                                                                                 │
# │  *   **Solid-State Batteries Gaining Traction:** Solid-state batteries are expected to become more prevalent    │
# │  in EVs by 2025. These batteries offer several advantages over traditional lithium-ion batteries, including     │
# │  higher energy density, faster charging times, and improved safety. Several automakers are investing heavily    │
# │  in solid-state battery technology, with plans to incorporate them into their vehicles in the coming years.     │
# │                                                                                                                 │
# │  *   **Charging Infrastructure Expansion:** Significant investments are being made in expanding EV charging     │
# │  infrastructure globally. By 2025, there will be a substantial increase in the number of public charging        │
# │  stations, including fast-charging options, to support the growing number of EVs on the road. Governments and   │
# │  private companies are collaborating to deploy charging infrastructure in urban areas, along highways, and in   │
# │  workplaces.                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 419c7d74-e57d-47f4-b57e-1bee14b548ba                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electric vehicles using the facts from the        │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 554bc95d-39a9-47ce-9e42-b2130e03938d                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Road Ahead: Electric Vehicles in 2025**                                                                  │
# │                                                                                                                 │
# │  The electric vehicle revolution is accelerating! By 2025, global EV sales are projected to exceed 20 million,  │
# │  fueled by lower battery costs and better charging options. A major game-changer is the rise of solid-state     │
# │  batteries, promising higher energy density, faster charging, and enhanced safety. Automakers are racing to     │
# │  integrate this tech. Addressing range anxiety, significant investments are expanding charging infrastructure   │
# │  worldwide. Expect more public charging stations, including fast-charging, in cities, along highways, and at    │
# │  workplaces. The future of EVs is bright, efficient, and increasingly accessible!                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# **The Road Ahead: Electric Vehicles in 2025**
#
# The electric vehicle revolution is accelerating! By 2025, global EV sales are projected to exceed 20 million, fueled by lower battery costs and better charging options. A major game-changer is the rise of solid-state batteries, promising higher energy density, faster charging, and enhanced safety. Automakers are racing to integrate this tech. Addressing range anxiety, significant investments are expanding charging infrastructure worldwide. Expect more public charging stations, including fast-charging, in cities, along highways, and at workplaces. The future of EVs is bright, efficient, and increasingly accessible!
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: cb069003-80a5-472e-bf81-ac3d0ed9c432                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **The Road Ahead: Electric Vehicles in 2025**                                                    │
# │                                                                                                                 │
# │  The electric vehicle revolution is accelerating! By 2025, global EV sales are projected to exceed 20 million,  │
# │  fueled by lower battery costs and better charging options. A major game-changer is the rise of solid-state     │
# │  batteries, promising higher energy density, faster charging, and enhanced safety. Automakers are racing to     │
# │  integrate this tech. Addressing range anxiety, significant investments are expanding charging infrastructure   │
# │  worldwide. Expect more public charging stations, including fast-charging, in cities, along highways, and at    │
# │  workplaces. The future of EVs is bright, efficient, and increasingly accessible!                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
